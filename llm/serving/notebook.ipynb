# %%
# !git clone https://github.com/nnminh322/AI_Agent.git
# !apt-get update && apt-get -qq install -y nginx
# %cd AI_Agent/llm/serving
# !pip install uv
# !uv pip install -r requirements.txt
# Out:
# Cloning into 'AI_Agent'...
# remote: Enumerating objects: 8094, done.
# remote: Counting objects: 100% (7642/7642), done.
# remote: Compressing objects: 100% (7026/7026), done.
# remote: Total 8094 (delta 583), reused 7466 (delta 411), pack-reused 452 (from 1)
# Receiving objects: 100% (8094/8094), 72.85 MiB | 16.51 MiB/s, done.
# Resolving deltas: 100% (778/778), done.
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 https://cli.github.com/packages stable InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,969 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,289 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,526 kB]
# Get:14 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:15 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,123 kB]
# Get:16 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.5 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,856 kB]
# Get:18 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,825 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,168 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,594 kB]
# Get:21 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,436 kB]
# Fetched 37.2 MB in 4s (9,359 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Preconfiguring packages ...
# Selecting previously unselected package nginx-common.
# (Reading database ... 125082 files and directories currently installed.)
# Preparing to unpack .../0-nginx-common_1.18.0-6ubuntu14.7_all.deb ...
# Unpacking nginx-common (1.18.0-6ubuntu14.7) ...
# Selecting previously unselected package libnginx-mod-http-geoip2.
# Preparing to unpack .../1-libnginx-mod-http-geoip2_1.18.0-6ubuntu14.7_amd64.deb ...
# Unpacking libnginx-mod-http-geoip2 (1.18.0-6ubuntu14.7) ...
# Selecting previously unselected package libnginx-mod-http-image-filter.
# Preparing to unpack .../2-libnginx-mod-http-image-filter_1.18.0-6ubuntu14.7_amd64.deb ...
# Unpacking libnginx-mod-http-image-filter (1.18.0-6ubuntu14.7) ...
# Selecting previously unselected package libnginx-mod-http-xslt-filter.
# Preparing to unpack .../3-libnginx-mod-http-xslt-filter_1.18.0-6ubuntu14.7_amd64.deb ...
# Unpacking libnginx-mod-http-xslt-filter (1.18.0-6ubuntu14.7) ...
# Selecting previously unselected package libnginx-mod-mail.
# Preparing to unpack .../4-libnginx-mod-mail_1.18.0-6ubuntu14.7_amd64.deb ...
# Unpacking libnginx-mod-mail (1.18.0-6ubuntu14.7) ...
# Selecting previously unselected package libnginx-mod-stream.
# Preparing to unpack .../5-libnginx-mod-stream_1.18.0-6ubuntu14.7_amd64.deb ...
# Unpacking libnginx-mod-stream (1.18.0-6ubuntu14.7) ...
# Selecting previously unselected package libnginx-mod-stream-geoip2.
# Preparing to unpack .../6-libnginx-mod-stream-geoip2_1.18.0-6ubuntu14.7_amd64.deb ...
# Unpacking libnginx-mod-stream-geoip2 (1.18.0-6ubuntu14.7) ...
# Selecting previously unselected package nginx-core.
# Preparing to unpack .../7-nginx-core_1.18.0-6ubuntu14.7_amd64.deb ...
# Unpacking nginx-core (1.18.0-6ubuntu14.7) ...
# Selecting previously unselected package nginx.
# Preparing to unpack .../8-nginx_1.18.0-6ubuntu14.7_amd64.deb ...
# Unpacking nginx (1.18.0-6ubuntu14.7) ...
# Setting up nginx-common (1.18.0-6ubuntu14.7) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/nginx.service → /lib/systemd/system/nginx.service.
# Setting up libnginx-mod-http-xslt-filter (1.18.0-6ubuntu14.7) ...
# Setting up libnginx-mod-http-geoip2 (1.18.0-6ubuntu14.7) ...
# Setting up libnginx-mod-mail (1.18.0-6ubuntu14.7) ...
# Setting up libnginx-mod-http-image-filter (1.18.0-6ubuntu14.7) ...
# Setting up libnginx-mod-stream (1.18.0-6ubuntu14.7) ...
# Setting up libnginx-mod-stream-geoip2 (1.18.0-6ubuntu14.7) ...
# Setting up nginx-core (1.18.0-6ubuntu14.7) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up nginx (1.18.0-6ubuntu14.7) ...
# Processing triggers for man-db (2.10.2-1) ...
# /content/AI_Agent/llm/serving
# Collecting uv
#   Downloading uv-0.9.8-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading uv-0.9.8-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 107.8 MB/s eta 0:00:00
# Installing collected packages: uv
# Successfully installed uv-0.9.8
# Using Python 3.12.12 environment at: /usr
# Resolved 143 packages in 822ms
# Prepared 43 packages in 12.92s
# Uninstalled 7 packages in 80ms
# Installed 43 packages in 129ms
#  + astor==0.8.1
#  + blake3==1.0.8
#  + cbor2==5.7.1
#  - click==8.3.0
#  + click==8.2.1
#  + compressed-tensors==0.11.0
#  + depyf==0.19.0
#  + diskcache==5.6.3
#  + dnspython==2.8.0
#  + email-validator==2.3.0
#  - fastapi==0.121.0
#  + fastapi==0.118.3
#  + fastapi-cli==0.0.14
#  + fastapi-cloud-cli==0.3.1
#  + gguf==0.17.1
#  + httptools==0.7.1
#  + interegular==0.3.3
#  - lark==1.3.1
#  + lark==1.2.2
#  + llguidance==0.7.30
#  - llvmlite==0.43.0
#  + llvmlite==0.44.0
#  + lm-format-enforcer==0.11.3
#  + loguru==0.7.3
#  + mistral-common==1.8.5
#  + msgspec==0.19.0
#  + ninja==1.13.0
#  - numba==0.60.0
#  + numba==0.61.2
#  + openai-harmony==0.0.8
#  + outlines-core==0.2.11
#  + partial-json-parser==0.2.1.1.post6
#  + prometheus-fastapi-instrumentator==7.1.0
#  + pybase64==1.4.2
#  + pycountry==24.6.1
#  + pydantic-extra-types==2.10.6
#  + pyngrok==7.4.1
#  + ray==2.51.1
#  + rich-toolkit==0.15.1
#  + rignore==0.7.6
#  + setproctitle==1.3.7
#  - setuptools==75.2.0
#  + setuptools==79.0.1
#  - starlette==0.49.3
#  + starlette==0.48.0
#  + uvloop==0.22.1
#  + vllm==0.11.0
#  + watchfiles==1.1.1
#  + xformers==0.0.32.post1
#  + xgrammar==0.1.25

# %%
# !uvicorn serving:app --host 127.0.0.1 --port 8000 > /dev/null > server.log 2>&1 &

# %%
# Quay lại thư mục gốc (nơi chứa 'etc' và 'serving')
# %cd ..

print("--- 2. Cấu hình Nginx... ---")

# 1. Copy file config từ thư mục "etc" của bạn
# (SỬA LẠI THÀNH "sites-available")
# !sudo cp ./etc/nginx/sites-available/llm_gateway.conf /etc/nginx/sites-available/

# 2. Kích hoạt config này (tạo symlink)
# !sudo ln -s /etc/nginx/sites-available/llm_gateway.conf /etc/nginx/sites-enabled/

# 3. Xóa file "default" của Nginx để tránh xung đột cổng 80
# !sudo rm -f /etc/nginx/sites-enabled/default

# 4. Kiểm tra xem file config của bạn có lỗi không
# !sudo nginx -t

# 5. Khởi động Nginx (dùng lệnh trực tiếp, vì Colab không có systemctl)
print("--- 3. Khởi động Nginx... ---")
# !sudo nginx
# Out:
# /content/AI_Agent/llm
# --- 2. Cấu hình Nginx... ---
# nginx: the configuration file /etc/nginx/nginx.conf syntax is ok
# nginx: configuration file /etc/nginx/nginx.conf test is successful
# --- 3. Khởi động Nginx... ---

# %%
# # Gửi request đến Nginx (cổng 80), không phải vLLM (cổng 8000)
# # Nhớ dùng API key của bạn
# !curl -H "X-API-Key: nhatminh123" \
#      -H "Content-Type: application/json" \
#      -d '{"prompts": "Hà Nội"}' \
#      http://localhost/chat
# Out:
# {"responses":[": Kinh phí tập huấn tập trung, không tổ chức riêng | Tạp chí Kinh tế và Dự báo\nThứ năm 21 Tháng十月 17 2019\n07:33 AM, Thứ ba, 14/02/2017\n(PEC) – Tính đến nay, Hà Nội đã tập huấn 2.077 lượt người, với tổng số 11.464 học viên, đạt 101,9% kế hoạch tập huấn của năm 2016. Trong đó, có 1.884 lượt người, 10.237 học viên tập huấn tập trung và 193 lượt người, 1.227 học viên tập huấn phân tán.\nCác lớp tập huấn được tổ chức theo từng đợt, với tổng số 47 đợt (trong đó đợt tập huấn tập trung là 42 đợt và đợt tập huấn phân tán là 5 đợt). Lớp học có thời gian 5-7 ngày, trong đó có một tuần liên thông (thời gian 3-5 ngày) để học viên tiếp cận thực tế tại đơn vị trực tiếp. Lớp học có kết quả tốt, sinh động, phù hợp với yêu cầu thực tiễn, học viên thực hành nhiều, học qua làm và làm qua học, được đánh giá cao. Các lớp tập huấn tập trung đã tạo điều kiện cho học viên tham gia học tập, thảo luận trong môi trường tập thể, từ đó cùng nhau học tập, chia sẻ kinh nghiệm, thúc đẩy tinh thần đoàn kết, làm việc cùng nhau. Đặc biệt, tại các lớp tập huấn phân tán, địa điểm tập huấn là tại các cơ sở, doanh nghiệp trực tiếp quản lý, điều hành, học viên được làm việc trực tiếp với người lãnh đạo, quản lý và nhân viên của đơn vị, có cơ hội học qua làm, làm qua học, được trải nghiệm, xử lý các vấn đề thực tế, qua đó nhận thức rõ hơn về thực tiễn và áp dụng kiến thức vào thực tiễn.\nLớp tập huấn tập trung cũng đã tạo cơ hội để học viên được tiếp xúc với tư duy, phương pháp làm việc, cách quản lý, lãnh"]}

# %%
from pyngrok import ngrok
import getpass

NGROK_AUTH_TOKEN = getpass.getpass("Nhập NGROK_AUTH_TOKEN của bạn: ")
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

public_url = ngrok.connect(80, "http")
print(f"API của bạn đang chạy tại: {public_url}")
# Out:
# Nhập NGROK_AUTH_TOKEN của bạn: ··········
# API của bạn đang chạy tại: NgrokTunnel: "https://06495fca5707.ngrok-free.app" -> "http://localhost:80"
