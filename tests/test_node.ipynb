# %%
from agents.state import MessageState
from node_and_edge.context_node import context_node
from node_and_edge.sys_msg_node import sys_msg_node
from node_and_edge.assistant_node import assistant_node
from node_and_edge.sql_note import sql_query_node
from node_and_edge.sql_verify_edge import sql_verify_edge
from node_and_edge.show import show
from langgraph.graph import StateGraph,START,END
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
state = MessageState()
state['question'] = "Cho tôi GMV theo từng tháng trong toàn bộ dữ liệu, kèm tỷ lệ tăng trưởng MoM và YoY cho mỗi tháng; sắp xếp theo thời gian để thấy xu hướng. hiển thị các tên trường bày tiếng Việt thay vì tiếng anh cho tôi hiểu"

# %%
graph = StateGraph(MessageState)

graph.add_node("context_node",context_node)
graph.add_node("sys_msg_node", sys_msg_node)
graph.add_node("assistant_node", assistant_node)
graph.add_node("sql_query_node",sql_query_node)
graph.add_node("show", show)

graph.add_edge(START, "context_node")
graph.add_edge("context_node", "sys_msg_node")
graph.add_edge("sys_msg_node", "assistant_node")
graph.add_edge("assistant_node", "sql_query_node")
graph.add_conditional_edges("sql_query_node", sql_verify_edge)
graph.add_edge("show", END)

# graph.add_edge("sql_query_node", END)
app = graph.compile()

# %%
from IPython.display import display, Image
display(Image(app.get_graph().draw_mermaid_png()))

# %%
state = app.invoke(state)

# %%
state
# Out:
# {'SQL_format': 'postgres',
#  'question': 'Cho tôi GMV theo từng tháng trong toàn bộ dữ liệu, kèm tỷ lệ tăng trưởng MoM và YoY cho mỗi tháng; sắp xếp theo thời gian để thấy xu hướng. hiển thị các tên trường bày tiếng Việt thay vì tiếng anh cho tôi hiểu',
#  'system_msg': "Bạn là chuyên gia viết SQL {postgres} để trả lời câu hỏi tiếng Việt/Anh dựa trên mô tả cơ sở dữ liệu cung cấp.\n\nQUY TẮC BẮT BUỘC:\n1) Chỉ tạo câu lệnh SELECT hợp lệ cho {postgres}; không được tạo DDL/DML.\n2) Luôn ghi rõ schema trước tên bảng (schema.table). Không tự suy ra bảng/cột không có trong mô tả.\n3) Ưu tiên cột/khóa có trong mô tả. Nếu thiếu thông tin, dùng comment ngắn dạng -- TODO:<vấn đề>.\n4) Mặc định giới hạn kết quả để an toàn:\n   - postgres/mysql: dùng LIMIT 200.\n   - mssql: dùng TOP 200 hoặc OFFSET…FETCH (nếu có ORDER BY).\n5) Đặt alias cột ngắn gọn, snake_case; tránh khoảng trắng; không dùng dấu tiếng Việt trong alias.\n6) Đối với lọc thời gian mơ hồ như “gần đây”, hiểu là 6 tháng gần nhất.\n7) Xử lý NULL an toàn với COALESCE khi tính toán/ghép chuỗi.\n8) Khi cần tìm kiếm không phân biệt hoa thường:\n   - postgres: ILIKE.\n   - mysql/mssql: LOWER(col) LIKE LOWER('%kw%') (nếu cần).\n9) Chỉ TRẢ VỀ duy nhất code block chứa SQL. Không kèm lời giải thích ngoài code.\n\nCHEAT-SHEET DIALCET:\n- postgres: CURRENT_DATE, DATE_TRUNC('month', ts), LIMIT n.\n- mysql: CURRENT_DATE, DATE_SUB(CURRENT_DATE, INTERVAL 6 MONTH), LIMIT n.\n- mssql: GETDATE(), DATEADD(MONTH, -6, GETDATE()), SELECT TOP n … / OFFSET…FETCH.\n\nBẠN SẼ NHẬN:\n- Mô tả DB (đầy đủ tên schema, bảng, cột, kiểu dữ liệu, quan hệ).\n- Câu hỏi người dùng.\n- (Nếu là lần sửa) SQL lỗi trước đó và thông báo lỗi.\n\nMỤC TIÊU:\n- Sinh đúng một truy vấn {postgres} trả lời trực tiếp câu hỏi, chạy được ngay.\n",
#  'db_description': '-- Làm sạch + tạo schema + set search_path\nDROP SCHEMA IF EXISTS olist CASCADE;\nCREATE SCHEMA olist;\nSET search_path TO olist, public;\n\n-- GELOCATION: bắt buộc zip prefix phải duy nhất (PK)\nCREATE TABLE olist_geolocation (\n    geolocation_id BIGSERIAL PRIMARY KEY,\n    geolocation_zip_code_prefix VARCHAR(10) NOT NULL,\n    geolocation_lat DOUBLE PRECISION,\n    geolocation_lng DOUBLE PRECISION,\n    geolocation_city VARCHAR(100),\n    geolocation_state VARCHAR(2)\n);\n\n-- CUSTOMERS\nCREATE TABLE olist_customers (\n    customer_id VARCHAR(50) PRIMARY KEY,\n    customer_unique_id VARCHAR(50) NOT NULL,\n    customer_zip_code_prefix VARCHAR(10) NOT NULL,\n    customer_city VARCHAR(100),\n    customer_state VARCHAR(2),\n    CONSTRAINT fk_customers_zip\n      FOREIGN KEY (customer_zip_code_prefix)\n      REFERENCES olist_geolocation(geolocation_zip_code_prefix)\n);\n\n-- SELLERS\nCREATE TABLE olist_sellers (\n    seller_id VARCHAR(50) PRIMARY KEY,\n    seller_zip_code_prefix VARCHAR(10) NOT NULL,\n    seller_city VARCHAR(100),\n    seller_state VARCHAR(2),\n    CONSTRAINT fk_sellers_zip\n      FOREIGN KEY (seller_zip_code_prefix)\n      REFERENCES olist_geolocation(geolocation_zip_code_prefix)\n);\n\n-- PRODUCTS\nCREATE TABLE olist_products (\n    product_id VARCHAR(50) PRIMARY KEY,\n    product_category_name VARCHAR(100),\n    product_name_length INTEGER,\n    product_description_length INTEGER,\n    product_photos_qty INTEGER,\n    product_weight_g INTEGER,\n    product_length_cm INTEGER,\n    product_height_cm INTEGER,\n    product_width_cm INTEGER\n);\n\n-- ORDERS\nCREATE TABLE olist_orders (\n    order_id VARCHAR(50) PRIMARY KEY,\n    customer_id VARCHAR(50) NOT NULL,\n    order_status VARCHAR(20),\n    order_purchase_timestamp TIMESTAMPTZ,\n    order_approved_at TIMESTAMPTZ,\n    order_delivered_carrier_date TIMESTAMPTZ,\n    order_delivered_customer_date TIMESTAMPTZ,\n    order_estimated_delivery_date TIMESTAMPTZ,\n    CONSTRAINT fk_orders_customer\n      FOREIGN KEY (customer_id) REFERENCES olist_customers(customer_id)\n);\n\n-- ORDER PAYMENTS\nCREATE TABLE olist_order_payments (\n    order_id VARCHAR(50) NOT NULL,\n    payment_sequential INTEGER NOT NULL,\n    payment_type VARCHAR(20),\n    payment_installments INTEGER,\n    payment_value NUMERIC(10, 2),\n    PRIMARY KEY (order_id, payment_sequential),\n    CONSTRAINT fk_payments_order\n      FOREIGN KEY (order_id) REFERENCES olist_orders(order_id) ON DELETE CASCADE\n);\n\n-- ORDER REVIEWS\nCREATE TABLE olist_order_reviews (\n    id BIGSERIAL PRIMARY KEY,\n    review_id VARCHAR(50),\n    order_id VARCHAR(50) NOT NULL,\n    review_score INTEGER,\n    review_comment_title VARCHAR(255),\n    review_comment_message TEXT,\n    review_creation_date TIMESTAMPTZ,\n    review_answer_timestamp TIMESTAMPTZ\n);\n\n-- ORDER ITEMS\nCREATE TABLE olist_order_items (\n    order_id VARCHAR(50) NOT NULL,\n    order_item_id INTEGER NOT NULL,\n    product_id VARCHAR(50) NOT NULL,\n    seller_id VARCHAR(50) NOT NULL,\n    shipping_limit_date TIMESTAMPTZ,\n    price NUMERIC(10, 2),\n    freight_value NUMERIC(10, 2),\n    PRIMARY KEY (order_id, order_item_id),\n    CONSTRAINT fk_items_order\n      FOREIGN KEY (order_id) REFERENCES olist_orders(order_id) ON DELETE CASCADE,\n    CONSTRAINT fk_items_product\n      FOREIGN KEY (product_id) REFERENCES olist_products(product_id),\n    CONSTRAINT fk_items_seller\n      FOREIGN KEY (seller_id) REFERENCES olist_sellers(seller_id)\n);\n\n-- TRANSLATION (đồng bộ prefix tên bảng nếu muốn)\nCREATE TABLE olist_product_category_translation (\n    product_category_name VARCHAR(100) PRIMARY KEY,\n    product_category_name_english VARCHAR(100)\n);\n\n-- Khuyến nghị index cho các cột FK (tăng tốc join/validate)\nCREATE INDEX idx_customers_zip   ON olist_customers(customer_zip_code_prefix);\nCREATE INDEX idx_sellers_zip     ON olist_sellers(seller_zip_code_prefix);\nCREATE INDEX idx_orders_customer ON olist_orders(customer_id);\nCREATE IND ...
#  'chat_history': '',
#  'SQL_statement': "SELECT \n    DATE_TRUNC('month', oi.shipping_limit_date) AS thang, \n    SUM(oi.price) AS gmv_thang,\n    SUM(oi.price) - LAG(SUM(oi.price)) OVER (ORDER BY DATE_TRUNC('month', oi.shipping_limit_date)) AS tang_truong_mom,\n    SUM(oi.price) - LAG(SUM(oi.price), 12) OVER (ORDER BY DATE_TRUNC('month', oi.shipping_limit_date)) AS tang_truong_yoy\nFROM \n    olist.olist_order_items oi\nGROUP BY \n    DATE_TRUNC('month', oi.shipping_limit_date)\nORDER BY \n    DATE_TRUNC('month', oi.shipping_limit_date)\nLIMIT 200;",
#  'SQL_num_retry': 0,
#  'SQL_data_results': [(datetime.datetime(2016, 9, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('194.47'),
#    None,
#    None),
#   (datetime.datetime(2016, 10, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('49580.55'),
#    Decimal('49386.08'),
#    None),
#   (datetime.datetime(2016, 12, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('10.90'),
#    Decimal('-49569.65'),
#    None),
#   (datetime.datetime(2017, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('80124.74'),
#    Decimal('80113.84'),
#    None),
#   (datetime.datetime(2017, 2, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('245982.01'),
#    Decimal('165857.27'),
#    None),
#   (datetime.datetime(2017, 3, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('343242.60'),
#    Decimal('97260.59'),
#    None),
#   (datetime.datetime(2017, 4, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('308148.32'),
#    Decimal('-35094.28'),
#    None),
#   (datetime.datetime(2017, 5, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('505655.46'),
#    Decimal('197507.14'),
#    None),
#   (datetime.datetime(2017, 6, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('469001.05'),
#    Decimal('-36654.41'),
#    None),
#   (datetime.datetime(2017, 7, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('465282.10'),
#    Decimal('-3718.95'),
#    None),
#   (datetime.datetime(2017, 8, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('560093.34'),
#    Decimal('94811.24'),
#    None),
#   (datetime.datetime(2017, 9, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('617046.12'),
#    Decimal('56952.78'),
#    None),
#   (datetime.datetime(2017, 10, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('658020.23'),
#    Decimal('40974.11'),
#    Decimal('657825.76')),
#   (datetime.datetime(2017, 11, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('883351.63'),
#    Decimal('225331.40'),
#    Decimal('833771.08')),
#   (datetime.datetime(2017, 12, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('898920.98'),
#    Decimal('15569.35'),
#    Decimal('898910.08')),
#   (datetime.datetime(2018, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('845279.18'),
#    Decimal('-53641.80'),
#    Decimal('765154.44')),
#   (datetime.datetime(2018, 2, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('819228.85'),
#    Decimal('-26050.33'),
#    Decimal('573246.84')),
#   (datetime.datetime(2018, 3, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('1030527.84'),
#    Decimal('211298.99'),
#    Decimal('687285.24')),
#   (datetime.datetime(2018, 4, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('958729.70'),
#    Decimal('-71798.14'),
#    Decimal('650581.38')),
#   (datetime.datetime(2018, 5, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('1084358.55'),
#    Decimal('125628.85'),
#    Decimal('578703.09')),
#   (datetime.datetime(2018, 6, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('870736.84'),
#    Decimal('-213621.71'),
#    Decimal('401735.79')),
#   (datetime.datetime(2018, 7, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('811132.08'),
#    Decimal('-59604.76'),
#    Decimal('345849.98')),
#   (datetime.datetime(2018, 8, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('1072147.70'),
#    Decimal('261015.62'),
#    Decimal('512054.36')),
#   (datetime.datetime(2018, 9, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('14502.50'),
#    Decimal('-1057645.20'),
#    Decimal('-602543.62')),
#   (datetime.datetime(2020, 2, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('145.98'),
#    Decimal('-14356.52'),
#    Decimal('-657874.25')),
#   (datetime.datetime(2020, 4, 1, 0, 0, tzinfo=datetime.timezone.utc),
#    Decimal('199.98'),
#    Decimal('54.00'),
#    Decimal('-883151.65'))]}

# %%
sql = state["SQL_statement"]

# %%
import pprint
pprint.pprint(sql)
# Out:
# ('SELECT \n'
#  "    TO_CHAR(DATE_TRUNC('month', o.order_purchase_timestamp), 'YYYY-MM') AS "
#  '"Tháng",\n'
#  '    COALESCE(SUM(oi.price), 0) AS "GMV",\n'
#  "    LAG(COALESCE(SUM(oi.price), 0)) OVER (ORDER BY DATE_TRUNC('month', "
#  'o.order_purchase_timestamp)) AS "GMV_tháng_trước",\n'
#  '    ROUND(\n'
#  '        CASE \n'
#  '            WHEN LAG(COALESCE(SUM(oi.price), 0)) OVER (ORDER BY '
#  "DATE_TRUNC('month', o.order_purchase_timestamp)) > 0 \n"
#  '            THEN \n'
#  '                100.0 * (COALESCE(SUM(oi.price), 0) - '
#  "LAG(COALESCE(SUM(oi.price), 0)) OVER (ORDER BY DATE_TRUNC('month', "
#  'o.order_purchase_timestamp))) / LAG(COALESCE(SUM(oi.price), 0)) OVER (ORDER '
#  "BY DATE_TRUNC('month', o.order_purchase_timestamp))\n"
#  '            ELSE 0 \n'
#  '        END, 2\n'
#  '    ) AS "Tăng_trưởng_MoM",\n'
#  "    LAG(COALESCE(SUM(oi.price), 0), 12) OVER (ORDER BY DATE_TRUNC('month', "
#  'o.order_purchase_timestamp)) AS "GMV_năm_trước",\n'
#  '    ROUND(\n'
#  '        CASE \n'
#  '            WHEN LAG(COALESCE(SUM(oi.price), 0), 12) OVER (ORDER BY '
#  "DATE_TRUNC('month', o.order_purchase_timestamp)) > 0 \n"
#  '            THEN \n'
#  '                100.0 * (COALESCE(SUM(oi.price), 0) - '
#  "LAG(COALESCE(SUM(oi.price), 0), 12) OVER (ORDER BY DATE_TRUNC('month', "
#  'o.order_purchase_timestamp))) / LAG(COALESCE(SUM(oi.price), 0), 12) OVER '
#  "(ORDER BY DATE_TRUNC('month', o.order_purchase_timestamp))\n"
#  '            ELSE 0 \n'
#  '        END, 2\n'
#  '    ) AS "Tăng_trưởng_YoY"\n'
#  'FROM \n'
#  '    olist.olist_orders o\n'
#  'JOIN \n'
#  '    olist.olist_order_items oi ON o.order_id = oi.order_id\n'
#  'WHERE \n'
#  "    o.order_status IN ('delivered', 'shipped') -- Lọc trạng thái hợp lệ, tùy "
#  'chỉnh nếu cần\n'
#  'GROUP BY \n'
#  "    DATE_TRUNC('month', o.order_purchase_timestamp)\n"
#  'ORDER BY \n'
#  "    DATE_TRUNC('month', o.order_purchase_timestamp)\n"
#  'LIMIT 200;')

# %%
data = state["SQL_data_results"]

# %%
print(type(data))
# Out:
# <class 'list'>

# %%
import pandas as pd

df = pd.DataFrame(data=data)

# %%
df
# Out:
#           0          1          2           3          4           5
# 0   2016-09     207.86       None        0.00       None        0.00
# 1   2016-10   41234.67     207.86    19737.71       None        0.00
# 2   2016-12      10.90   41234.67      -99.97       None        0.00
# 3   2017-01  114197.09      10.90  1047579.72       None        0.00
# 4   2017-02  237994.76  114197.09      108.41       None        0.00
# 5   2017-03  362912.17  237994.76       52.49       None        0.00
# 6   2017-04  345999.86  362912.17       -4.66       None        0.00
# 7   2017-05  497190.99  345999.86       43.70       None        0.00
# 8   2017-06  426699.11  497190.99      -14.18       None        0.00
# 9   2017-07  488961.75  426699.11       14.59       None        0.00
# 10  2017-08  560250.05  488961.75       14.58       None        0.00
# 11  2017-09  613902.25  560250.05        9.58       None        0.00
# 12  2017-10  653922.99  613902.25        6.52     207.86   314497.80
# 13  2017-11  995028.84  653922.99       52.16   41234.67     2313.09
# 14  2017-12  732492.52  995028.84      -26.38      10.90  6720014.86
# 15  2018-01  934588.96  732492.52       27.59  114197.09      718.40
# 16  2018-02  836447.78  934588.96      -10.50  237994.76      251.46
# 17  2018-03  970472.24  836447.78       16.02  362912.17      167.41
# 18  2018-04  990553.59  970472.24        2.07  345999.86      186.29
# 19  2018-05  985299.50  990553.59       -0.53  497190.99       98.17
# 20  2018-06  862907.33  985299.50      -12.42  426699.11      102.23
# 21  2018-07  874652.04  862907.33        1.36  488961.75       78.88
# 22  2018-08  846153.30  874652.04       -3.26  560250.05       51.03
# 23  2018-09     145.00  846153.30      -99.98  613902.25      -99.98
